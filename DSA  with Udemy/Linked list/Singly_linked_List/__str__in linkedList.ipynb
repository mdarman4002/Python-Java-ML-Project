# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.next = None
        
class LinkedList:
    def __init__(self,value):
        self.head = None
        self.tail = None
        self.length = 0
    def append(self,value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length +=1
    def __str__(self):
        temp_node = self.head
        result = " "
        while temp_node is not None:
            result += str(temp_node.value)
            temp_node = temp_node.next
            if temp_node is not None:
                result = result + "->"
        return result
newLinkedList = LinkedList(None)
newLinkedList.append(10)
newLinkedList.append(20)
newLinkedList.append(30)
print(newLinkedList)

print("head: " ,newLinkedList.head.value)
print('tail: ',newLinkedList.tail.value)
# Out:
#  10->20->30
# head:  10
# tail:  30

# %% [markdown]
# # isert an Element at the begining of the linked list

# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.next = None
        
class LinkedList:
    def __init__(self,value):
        self.head = None
        self.tail = None
        self.length = 0
    def append(self,value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length +=1
    def __str__(self):
        temp_node = self.head
        result = " "
        while temp_node is not None:
            result += str(temp_node.value)
            temp_node = temp_node.next
            if temp_node is not None:
                result = result + "->"
        return result
    def begin_append(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head = new_node
        self.length += 1

        
newLinkedList = LinkedList(None)
newLinkedList.append(10)
newLinkedList.begin_append(20)
newLinkedList.append(30)
print(newLinkedList)

print("head: " ,newLinkedList.head.value)
print('tail: ',newLinkedList.tail.value)  


# newLinkedList = LinkedList(None)
# newLinkedList.append(10)
# newLinkedList.begin_append(20)
# newLinkedList.append(30)
# print(newLinkedList)

newLinkedList.begin_append(100)
print(newLinkedList)

print("head:", newLinkedList.head.value)
print("tail:", newLinkedList.tail.value)
print("length:", newLinkedList.length)
# Out:
#  20->10->30
# head:  20
# tail:  30
#  100->20->10->30
# head: 100
# tail: 30
# length: 4

# %%
def __str__(self):
        temp_node = self.head
        result = ''
        while temp_node is not None:
            result += str(temp_node.value)
            temp_node = temp_node.next
            if temp_node is not None and temp_node.next is not None:
                result += " -> "
            temp_node = temp_node.next
        return result

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0
    def append(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1
        
    def __str__(self):
        temp_node = self.head
        result = ""
        while temp_node is not None:
            result += str(temp_node.value)
            temp_node = temp_node.next
            if temp_node is not None:
                result += "->"
        return result

    

    def begin_append(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head = new_node
        self.length += 1

newLinkedList = LinkedList()
newLinkedList.append(10)
newLinkedList.begin_append(20)
newLinkedList.append(30)
.
print(newLinkedList)

print("head:", newLinkedList.head.value)
print("tail:", newLinkedList.tail.value)
print("length:", newLinkedList.length)
# Out:
# 20->10->30
# head: 20
# tail: 30
# length: 3

# %% [markdown]
# # insertion in single linked list using index

# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.next = None
        
class LinkedList:
    def __init__(self,value):
        self.head = None
        self.tail = None
        self.length = 0
    def append(self,value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length +=1
    def __str__(self):
        temp_node = self.head
        result = " "
        while temp_node is not None:
            result += str(temp_node.value)
            temp_node = temp_node.next
            if temp_node is not None:
                result = result + "->"
        return result
    def begin_append(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head = new_node
        self.length += 1
        
    def insertAnyWhere(self,index,value):
        new_node = Node(value)
        if 0< index >= self.length +1:
            
            if index == 0:
                self.head = new_node
                self.tail = new_node
                self.length +=1
                
            elif self.length +1 == index:
                self.tail.next = new_node
                new_node.next = self.tail
                self.length += 1
                
            else:
                temp_node = self.head
                for i in range(index - 1):
                    temp_node = temp_node.next
                temp_node.next = new_node
                new_node.next = new_node
        else:
            print("invalid ")
                
        
newLinkedList = LinkedList(0)
newLinkedList.append(10)
newLinkedList.begin_append(20)
newLinkedList.append(30)
# insert anywhere
newLinkedList.insertAnyWhere(1,40)
print(newLinkedList)

print("head: " ,newLinkedList.head.value)
print('tail: ',newLinkedList.tail.value)  


# newLinkedList = LinkedList(None)
# newLinkedList.append(10)
# newLinkedList.begin_append(20)
# newLinkedList.append(30)
# print(newLinkedList)

newLinkedList.begin_append(100)
newLinkedList.insertAnyWhere(2,90)
print(newLinkedList)

print("head:", newLinkedList.head.value)
print("tail:", newLinkedList.tail.value)
print("length:", newLinkedList.length)
# Out:
# invalid
#  20->10->30
# head:  20
# tail:  30
# invalid
#  100->20->10->30
# head: 100
# tail: 30
# length: 4

# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.next = None
class linkedList:
    def __init__(self):
    
        self.head = None
        self.tail = None
        
    def Append(self,value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
            
    def __str__(self):
        temp_node = self.head
        while temp_node is not None:
            result = temp_node
        return result
        
        
    
        
    
        
new_list = linkedList()
new_list.Append(20)
new_list.Append(30)
new_list.Append(50)
print(new_list)
print("head: ",new_list.head.value)
print("tail: ",new_list.tail.value)

# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.next = None
        
class LinkedList:
    def __init__(self,value):
        self.head = None
        self.tail = None
        self.length = 0
    def append(self,value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length +=1
    
    # def begin_append(self, value):
    #     new_node = Node(value)
    #     if self.head is None:
    #         self.head = new_node
    #         self.tail = new_node
    #     else:
    #         new_node.next = self.head
    #         self.head = new_node
    #     self.length += 1
        
    def insertAnyWhere(self,index,value):
        new_node = Node(value)
        if 0< index > self.length :
            print("Invalid index")
            
        elif index == 0:
                self.head = new_node
                self.tail = new_node
                self.length +=1
                
            # elif self.length +1 == index:
            #     self.tail.next = new_node
            #     new_node.next = self.tail
            #     self.length += 1
                
        else:
            temp_node = self.head
            for i in range(index - 1):
                temp_node = temp_node.next
            temp_node.next = new_node
            new_node.next = new_node
    def __str__(self):
        temp_node = self.head
        result = " "
        while temp_node is not None:
            result += str(temp_node.value)
            temp_node = temp_node.next
            if temp_node is not None:
                result = result + "->"
        return result
        
                
        
newLinkedList = LinkedList(0)
newLinkedList.append(10)
# newLinkedList.begin_append(20)
newLinkedList.append(30)
# insert anywhere
newLinkedList.insertAnyWhere(1,40)
print(newLinkedList)

print("head: " ,newLinkedList.head.value)
print('tail: ',newLinkedList.tail.value)  


# newLinkedList = LinkedList(None)
# newLinkedList.append(10)
# newLinkedList.begin_append(20)
# newLinkedList.append(30)
# print(newLinkedList)

newLinkedList.begin_append(100)
newLinkedList.insertAnyWhere(2,90)
print(newLinkedList)

print("head:", newLinkedList.head.value)
print("tail:", newLinkedList.tail.value)
print("length:", newLinkedList.length)
