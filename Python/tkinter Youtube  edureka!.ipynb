# %%
import tkinter as tk
from tkinter import ttk 
from tkinter import scrolledtext

window=tk.Tk()
window.geometry("300x400")
#grid
l1=ttk.Label(window, text = "name: " , font="Gill")
l1.grid(row=0, column=0)

l2=ttk.Label(window, text="branch: ", font="Gill")
l2.grid(row=1, column=0)

#entry
e1s=tk.StringVar()
e1=ttk.Entry(window, width=20, textvariable=e1s)
e1.grid(row = 0, column=1, sticky= "W")

e2s=tk.StringVar()
e2=ttk.Entry(window, width=20, textvariable=e2s)
e2.grid(row=1, column=1,sticky= "W")

 # Button
#b1=ttk.Button(window, text= "click here")
# def clicked():
#     l1.configure(text="Button was clicked")
#     bt= Button(window, text ="Enter", command=clicked)

# combobox
l_combo=ttk.Label(window, text="select gender", font= "Gill")
l_combo.grid(row=3, column=0)
combo= ttk.Combobox(window, text ="select gender", width=18)
combo['values'] = ("male", "female", "others")
combo.grid(row= 3, column= 1, sticky= "W")

#  checkbutton

# check_button= BooleanVar()
# check_button.set(True)
# check= heckbutton(window, text="select", var= check_button)
# check.grid(row= 4, column=1)

#radiobutton
lrad=ttk.Label(window, text= "select cource", font="Gill")
lrad.grid(row=5, column=0)
rad1= ttk.Radiobutton(window, text= 'cse', value=1).grid(row=5, column=1)
rad2= ttk.Radiobutton(window, text= "bca",value=2).grid(row=5, column=2)
rad3= ttk.Radiobutton(window, text= "mba", value=3).grid(row=5, column=3)

#ScrolledText
txt=scrolledtext.ScrolledText(window,width=40, height=15)

#spin
spin = ttk.Spinbox(window,from_=0, to=100, width=5)
window.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from tkinter import messagebox

win=tk.Tk()

#Radiobutton

# label=ttk.Label(win, text="choose").grid(row=0 ,column=0)
# r1=ttk.Radiobutton(win,text= "Arman", value=1)
# r2=ttk.Radiobutton(win,text= "faishal", value=2)
# r3=ttk.Radiobutton(win,text= "firdosh", value=3)

# r1.grid(row=0, column=1)
# r2.grid(row=0, column=2)
# r3.grid(row=0, column=3)

#messagebox
def clicked():
    messagebox.showinfo("Message title", "Message content")
    btn=Button(win, text= "Enter", command=clicked)

win.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
window=tk.Tk()

spin = ttk.Spinbox(window,from_=0, to=100, width=5)
window.mainloop()
