# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\DELL\Desktop\Covid-19 project\4. Covid_19_data.csv")

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data[data.Region == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
# df.count()
#df.isnull()   measing value
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull().head(20)   # true means null value present in data
# Out:
#      Date  State  Region  Confirmed  Deaths  Recovered
# 0   False   True   False      False   False      False
# 1   False   True   False      False   False      False
# 2   False   True   False      False   False      False
# 3   False   True   False      False   False      False
# 4   False   True   False      False   False      False
# 5   False   True   False      False   False      False
# 6   False   True   False      False   False      False
# 7   False   True   False      False   False      False
# 8   False   True   False      False   False      False
# 9   False   True   False      False   False      False
# 10  False   True   False      False   False      False
# 11  False   True   False      False   False      False
# 12  False   True   False      False   False      False
# 13  False   True   False      False   False      False
# 14  False   True   False      False   False      False
# 15  False   True   False      False   False      False
# ...

# %%
data.isnull().sum()    # how much data is null
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as  sns

# %%
import matplotlib.pyplot as plt  # this library provide better visualization

# %%
sns.heatmap(data.isnull())  # white space represent null value 
plt.show()

# %% [markdown]
# # Show the number of confirmed, death and reconvered cases in each Region.

# %%
#df.groupby('Region').sum().head(50)
#df.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(20)
#df.groupby('Region')['Confirmed', 'Recovered'].sum()

# %%
data.head(15)
# Out:
#          Date State               Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN          Afghanistan       1939      60        252
# 1   4/29/2020   NaN              Albania        766      30        455
# 2   4/29/2020   NaN              Algeria       3848     444       1702
# 3   4/29/2020   NaN              Andorra        743      42        423
# 4   4/29/2020   NaN               Angola         27       2          7
# 5   4/29/2020   NaN  Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN            Argentina       4285     214       1192
# 7   4/29/2020   NaN              Armenia       1932      30        900
# 8   4/29/2020   NaN              Austria      15402     580      12779
# 9   4/29/2020   NaN           Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN              Bahamas         80      11         23
# 11  4/29/2020   NaN              Bahrain       2921       8       1455
# ...

# %%
data.groupby("Deaths").sum().head(10)
# Out:
#         Confirmed  Recovered
# Deaths
# 0            3440     143479
# 1            4463       3227
# 2            2573       1654
# 3            2257       1417
# 4            3705       2914
# 5             141          0
# 6            5753       3876
# 7            4886       2153
# 8            6641       4420
# 9            4448       2161

# %%
data.groupby("Region").sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
data.groupby("Region")["Confirmed","Recovered"].sum().head(8)  # show the data in descending order
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_9124/775779539.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby("Region")["Confirmed","Recovered"].sum().head(8)  # show the data in descending order
#                      Confirmed  Recovered
# Region
# Afghanistan               1939        252
# Albania                    766        455
# Algeria                   3848       1702
# Andorra                    743        423
# Angola                      27          7
# Antigua and Barbuda         24         11
# Argentina                 4285       1192
# Armenia                   1932        900

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False)
# Out:
# Region
# US                       1039909
# Spain                     236899
# Italy                     203591
# France                    166543
# UK                        166441
#                           ...
# Sao Tome and Principe          8
# Papua New Guinea               8
# Bhutan                         7
# Western Sahara                 6
# Yemen                          6
# Name: Confirmed, Length: 187, dtype: int64

# %% [markdown]
# # Remove all the records where Confirmed Cases is Less Than 10.

# %%
#df.Confirmed < 10
#df[df.Confirmed < 10]
#df[~(df.Confirmed < 10)]
#df = df[~(df.Confirmed < 10)]

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data[data.Confirmed < 10].head()
# Out:
#           Date State                 Region  Confirmed  Deaths  Recovered
# 18   4/29/2020   NaN                 Bhutan          7       0          5
# 98   4/29/2020   NaN             MS Zaandam          9       2          0
# 105  4/29/2020   NaN             Mauritania          8       1          6
# 126  4/29/2020   NaN       Papua New Guinea          8       0          0
# 140  4/29/2020   NaN  Sao Tome and Principe          8       0          4

# %%
data[~(data.Confirmed < 10)].head()  # less than 10 confirmed case removed
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data = data[~(data.Confirmed < 10)].head()
data
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %% [markdown]
# # In which Region, maximum number of Confirmed cases were recorded ?

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %% [markdown]
# # In which Region, maximum number of Confirmed cases were recorded ?

# %%
data.groupby("Region").Confirmed.sum().sort_values(ascending = False).head()
# Out:
# Region
# Algeria        3848
# Afghanistan    1939
# Albania         766
# Andorra         743
# Angola           27
# Name: Confirmed, dtype: int64

# %% [markdown]
# # In which Region, minimum number of Deaths cases were recorded ?

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.groupby("Region").Deaths.sum()
# Out:
# Region
# Afghanistan     60
# Albania         30
# Algeria        444
# Andorra         42
# Angola           2
# Name: Deaths, dtype: int64

# %%
data.groupby("Region").Deaths.sum().sort_values(ascending = True).head(10)
# Out:
# Region
# Angola           2
# Albania         30
# Andorra         42
# Afghanistan     60
# Algeria        444
# Name: Deaths, dtype: int64

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data[data.Region == 'Angola']
# Out:
#         Date State  Region  Confirmed  Deaths  Recovered
# 4  4/29/2020   NaN  Angola         27       2          7

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
import pandas as pd
data_ = pd.read_csv(r"C:\Users\DELL\Desktop\Covid-19 project\4. Covid_19_data.csv").head()
data_
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
#ex_data = pd.read_excel("data_structure.xlsx")
